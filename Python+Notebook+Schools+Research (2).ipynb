# %% [markdown]
# # Python Machine Learning Notebook

# %%
import numpy as np
import pandas as pd

from pandas import DataFrame

import sklearn
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn import tree

import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading in the dataset

# %%
#Importing CSV file using pandas read_csv method
data = pd.read_csv("Summer Data\datasets\Florida Dropout Rates.csv", sep=',', index_col=1)
data
# Out:
#                District #  Student Total  (%) Minority Rate  White %    Free  \
# District Name
# ALACHUA                 1          28157             0.4403   0.4549   13496
# BAKER                   2           4985             0.1354   0.8333    2617
# BAY                     3          27055             0.2114   0.7123   11932
# BRADFORD                4           3238             0.2559   0.7112    1739
# BREVARD                 5          71234             0.2774   0.6296   26157
# BROWARD                 6         262663             0.6940   0.2409  137198
# CALHOUN                 7           2278             0.1782   0.7638    1332
# CHARLOTTE               8          16263             0.2211   0.7149    8296
# CITRUS                  9          15069             0.1232   0.8161    8249
# CLAY                   10          35524             0.2383   0.6866   11679
# COLLIER                11          44414             0.5900   0.3697   24803
# COLUMBIA               12          10137             0.2621   0.6800    5376
# MIAMI-DADE             13         356232             0.9048   0.0773  233130
# DESOTO                 14           4700             0.5521   0.4209       0
# DIXIE                  15           2085             0.1176   0.8445      42
# DUVAL                  16         127661             0.5347   0.3774   59787
# ESCAMBIA               17          40753             0.4030   0.4963   20791
# FLAGLER                18          12753             0.2852   0.6317    6443
# FRANKLIN               19           1285             0.1598   0.7981       0
# GADSDEN                20           6006             0.9453   0.0328       0
# GILCHRIST              21           2606             0.1016   0.8677    1348
# GLADES                 22           1531             0.4376   0.3945     761
# GULF                   23           1863             0.1632   0.7982     887
# HAMILTON               24           1686             0.5433   0.4265       0
# HARDEE                 25           5152             0.6511   0.3203    3684
# HENDRY                 26           6906             0.7696   0.2163    5277
# HERNANDO               27          22068             0.2343   0.7056   12211
# HIGHLANDS              28          12199             0.4866   0.4611    7958
# HILLSBOROUGH           29         203432             0.5532   0.3679  108664
# HOLMES                 30           3342             0.0673   0.8996    1945
# ...                   ...            ...                ...      ...     ...
# LEVY                   38           5506             0.2258   0.7306       0
# LIBERTY                39           1435             0.2034   0.7764     145
# MADISON                40           2532             0.5987   0.3795     433
# MANATEE                41          46703             0.4496   0.4994   24626
# MARION                 42          42107             0.3942   0.5345   11735
# MARTIN                 43          18792             0.3367   0.6193    5555
# MONROE                 44           8489             0.4486   0.5060    3293
# NASSAU                 45          11156             0.1158   0.8314    4161
# OKALOOSA               46          30216             0.2111   0.6847   10512
# OKEECHOBEE             47           6400             0.4563   0.4971    4355
# ORANGE                 48         187092             0.6295   0.2967   68574
# OSCEOLA                49          58203             0.6825   0.2626   32701
# PALM BEACH             50         182898             0.5944   0.3412  101916
# PASCO                  51          68103             0.2681   0.6593   30971
# PINELLAS               52         103410             0.3327   0.5809   21452
# POLK                   53          97957             0.5047   0.4428   39070
# PUTNAM                 54          11109             0.4063   0.5484    8059
# ST. JOHNS              55          33643             0.1471   0.7953    6413
# ST. LUCIE              56          39475             0.5657   0.3771   23764
# SANTA ROSA             57          25892             0.1083   0.8011    9031
# SARASOTA               58          41395             0.2762   0.6512   16264
# SEMINOLE               59          64846             0.3733   0.5446   24439
# SUMTER                 60           8281             0.2588   0.6856    4261
# SUWANNEE               61           5979             0.2968   0.6577     938
# TAYLOR                 62           3026             0.2737   0.6738       0
# UNION                  63           2365             0.1649   0.7852    1326
# VOLUSIA                64          61237             0.3348   0.6041   33940
# WAKULLA                65           5072             0.1315   0.8090    2227
# WALTON                 66           8068             0.1643   0.7761    3690
# WASHINGTON             67           3310             0.1907   0.7545       1
#
#                Reduced  (%) Poverty Rate  (%) Dropout Rate  \
# District Name
# ALACHUA           1382            0.5284             0.024
# BAKER              350            0.5952             0.004
# BAY               2524            0.5343             0.014
# BRADFORD           261            0.6177             0.015
# BREVARD           3345            0.4142             0.006
# BROWARD          20260            0.5995             0.019
# CALHOUN            196            0.6708             0.020
# CHARLOTTE         1629            0.6103             0.024
# CITRUS            1291            0.6331             0.013
# CLAY              2906            0.4106             0.010
# COLLIER           2517            0.6151             0.016
# COLUMBIA           791            0.6084             0.003
# MIAMI-DADE       30815            0.7409             0.027
# DESOTO               0            0.0000             0.044
# DIXIE                4            0.0221             0.008
# DUVAL             4415            0.5029             0.029
# ESCAMBIA          2356            0.5680             0.010
# FLAGLER            797            0.5677             0.009
# FRANKLIN             0            0.0000             0.032
# GADSDEN              0            0.0000             0.049
# GILCHRIST          263            0.6182             0.005
# GLADES              45            0.5265             0.009
# GULF               121            0.5411             0.005
# HAMILTON             0            0.0000             0.019
# HARDEE             357            0.7844             0.044
# HENDRY             345            0.8141             0.029
# HERNANDO          1850            0.6372             0.025
# HIGHLANDS          839            0.7211             0.027
# HILLSBOROUGH     13383            0.5999             0.007
# HOLMES             368            0.6921             0.019
# ...                ...               ...               ...
# LEVY                 0            0.0000             0.014
# LIBERTY             13            0.1101             0.004
# MADISON             42            0.1876             0.010
# MANATEE           2620            0.5834             0.034
# MARION            1586            0.3164             0.014
# MARTIN             736            0.3348             0.007
# MONROE             594            0.4579             0.019
# NASSAU             834            0.4477             0.003
# OKALOOSA          2095            0.4172             0.012
# OKEECHOBEE         438            0.7489             0.023
# ORANGE            9652            0.4181             0.009
# OSCEOLA           4609            0.6410             0.004
# PALM BEACH        7198            0.5966             0.047
# PASCO             4930            0.5272             0.008
# PINELLAS          4261            0.2487             0.012
# POLK              5062            0.4505             0.034
# PUTNAM             513            0.7716             0.036
# ST. JOHNS         1264            0.2282             0.007
# ST. LUCIE         2600            0.6679             0.014
# SANTA ROSA        1813            0.4188             0.008
# SARASOTA          2293            0.4483             0.010
# SEMINOLE          5153            0.4563             0.003
# SUMTER             612            0.5885             0.023
# SUWANNEE           102            0.1739             0.008
# TAYLOR               0            0.0000             0.042
# UNION              141            0.6203             0.009
# VOLUSIA           3901            0.6179             0.007
# WAKULLA            405            0.5189             0.009
# WALTON             596            0.5312             0.037
# WASHINGTON           0            0.0003             0.015
#
#                (%) Discipline Rate (Cat) Dropout Rate         ...           \
# District Name                                                 ...
# ALACHUA                     0.0746               High         ...
# BAKER                       0.1627               Safe         ...
# BAY                         0.1917               Safe         ...
# BRADFORD                    0.2312               Safe         ...
# BREVARD                     0.1399               Safe         ...
# BROWARD                     0.0806               Safe         ...
# CALHOUN                     0.1260               Safe         ...
# CHARLOTTE                   0.1583               High         ...
# CITRUS                      0.2470               Safe         ...
# CLAY                        0.1591               Safe         ...
# COLLIER                     0.1091               Safe         ...
# COLUMBIA                    0.2129               Safe         ...
# MIAMI-DADE                  0.1011               High         ...
# DESOTO                      0.0756               High         ...
# DIXIE                       0.1760               Safe         ...
# DUVAL                       0.2051               High         ...
# ESCAMBIA                    0.1875               Safe         ...
# FLAGLER                     0.1301               Safe         ...
# FRANKLIN                    0.1708               High         ...
# GADSDEN                     0.2027               High         ...
# GILCHRIST                   0.1945               Safe         ...
# GLADES                      0.1141               Safe         ...
# GULF                        0.2134               Safe         ...
# HAMILTON                    0.3123               Safe         ...
# HARDEE                      0.0766               High         ...
# HENDRY                      0.2013               High         ...
# HERNANDO                    0.2203               High         ...
# HIGHLANDS                   0.2628               High         ...
# HILLSBOROUGH                0.1749               Safe         ...
# HOLMES                      0.1556               Safe         ...
# ...                            ...                ...         ...
# LEVY                        0.2609               Safe         ...
# LIBERTY                     0.1783               Safe         ...
# MADISON                     0.3634               Safe         ...
# MANATEE                     0.2074               High         ...
# MARION                      0.2087               Safe         ...
# MARTIN                      0.0995               Safe         ...
# MONROE                      0.1248               Safe         ...
# NASSAU                      0.1445               Safe         ...
# OKALOOSA                    0.1233               Safe         ...
# OKEECHOBEE                  0.2168               Safe         ...
# ORANGE                      0.1283               Safe         ...
# OSCEOLA                     0.1150               Safe         ...
# PALM BEACH                  0.1108               High         ...
# PASCO                       0.1309               Safe         ...
# PINELLAS                    0.1808               Safe         ...
# POLK                        0.1740               High         ...
# PUTNAM                      0.2058               High         ...
# ST. JOHNS                   0.0926               Safe         ...
# ST. LUCIE                   0.0923               Safe         ...
# SANTA ROSA                  0.0978               Safe         ...
# SARASOTA                    0.1060               Safe         ...
# SEMINOLE                    0.0950               Safe         ...
# SUMTER                      0.2371               Safe         ...
# SUWANNEE                    0.1921               Safe         ...
# TAYLOR                      0.4195               High         ...
# UNION                       0.1964               Safe         ...
# VOLUSIA                     0.2026               Safe         ...
# WAKULLA                     0.1850               Safe         ...
# WALTON                      0.1388               High         ...
# WASHINGTON                  0.1941               Safe         ...
#
#               (Cat) Poverty Status (Cat) Minority Rate (Cat) AP Participation  \
# District Name
# ALACHUA                       Safe       Below Average                 Normal
# BAKER                         Safe       Below Average                   High
# BAY                           Safe       Below Average                 Normal
# BRADFORD                      Safe       Below Average                 Normal
# BREVARD                       Safe       Below Average                 Normal
# BROWARD                       Safe       Above Average                 Normal
# CALHOUN                       High       Below Average                 Normal
# CHARLOTTE                     Safe       Below Average                 Normal
# CITRUS                        High       Below Average                 Normal
# CLAY                          Safe       Below Average                 Normal
# COLLIER                       Safe       Above Average                 Normal
# COLUMBIA                                 Below Average                 Normal
# MIAMI-DADE                    High       Above Average                 Normal
# DESOTO                        Safe       Above Average                   High
# DIXIE                         Safe       Below Average                   High
# DUVAL                         Safe       Above Average                 Normal
# ESCAMBIA                      Safe       Below Average                 Normal
# FLAGLER                       Safe       Below Average                 Normal
# FRANKLIN                      Safe       Below Average                   High
# GADSDEN                       Safe       Above Average                   High
# GILCHRIST                     High       Below Average                 Normal
# GLADES                        Safe       Below Average                   High
# GULF                          Safe       Below Average                 Normal
# HAMILTON                      Safe       Above Average                 Normal
# HARDEE                        High       Above Average                   High
# HENDRY                        High       Above Average                   High
# HERNANDO                      High       Below Average                 Normal
# HIGHLANDS                     High       Below Average                 Normal
# HILLSBOROUGH                  Safe       Above Average                 Normal
# HOLMES                        High       Below Average                 Normal
# ...                            ...                 ...                    ...
# LEVY                          Safe       Below Average                   High
# LIBERTY                       Safe       Below Average                   High
# MADISON                       Safe       Above Average                 Normal
# MANATEE                       Safe       Below Average                 Normal
# MARION                        Safe       Below Average                 Normal
# MARTIN                        Safe       Below Average                 Normal
# MONROE                        Safe       Below Average                 Normal
# NASSAU                        Safe       Below Average                 Normal
# OKALOOSA                      Safe       Below Average                 Normal
# OKEECHOBEE                    High       Below Average                 Normal
# ORANGE                        Safe       Above Average                 Normal
# OSCEOLA                       High       Above Average                 Normal
# PALM BEACH                    Safe       Above Average                 Normal
# PASCO                         Safe       Below Average                 Normal
# PINELLAS                      Safe       Below Average                 Normal
# POLK                          Safe       Above Average                 Normal
# PUTNAM                        High       Below Average                   High
# ST. JOHNS                     Safe       Below Average                 Normal
# ST. LUCIE                     High       Above Average                   High
# SANTA ROSA                    Safe       Below Average                 Normal
# SARASOTA                      Safe       Below Average                 Normal
# SEMINOLE                      Safe       Below Average                 Normal
# SUMTER                        Safe       Below Average                   High
# SUWANNEE                      Safe       Below Average                 Normal
# TAYLOR                        Safe       Below Average                 Normal
# UNION                         High       Below Average                   High
# VOLUSIA                       High       Below Average                 Normal
# WAKULLA                       Safe       Below Average                 Normal
# WALTON                        Safe       Below Average                 Normal
# WASHINGTON                    Safe       Below Average                   High
#
#               (Cat) AP Pass Rate (Cat) ACT Test Takers (Cat) Percent Present  \
# District Name
# ALACHUA                     High                   Low                  Safe
# BAKER                        Low                   Low                   Low
# BAY                         High                   Low                  Safe
# BRADFORD                     Low                   Low                   Low
# BREVARD                     High                  High                  Safe
# BROWARD                     High                   Low                  Safe
# CALHOUN                      Low                   Low                   Low
# CHARLOTTE                    Low                   Low                  Safe
# CITRUS                       Low                   Low                  Safe
# CLAY                        High                   Low                  Safe
# COLLIER                     High                   Low                  Safe
# COLUMBIA                     Low                   Low                  Safe
# MIAMI-DADE                   Low                   Low                  Safe
# DESOTO                       Low                   Low                  Safe
# DIXIE                        Low                  High                   Low
# DUVAL                        Low                   Low                  Safe
# ESCAMBIA                     Low                   Low                  Safe
# FLAGLER                     High                   Low                  Safe
# FRANKLIN                     Low                  High                   Low
# GADSDEN                      Low                   Low                  Safe
# GILCHRIST                    Low                  High                   Low
# GLADES                       Low                  High                  Safe
# GULF                         Low                   Low                  Safe
# HAMILTON                     Low                  High                   Low
# HARDEE                       Low                  High                  Safe
# HENDRY                       Low                  High                   Low
# HERNANDO                     Low                   Low                  Safe
# HIGHLANDS                    Low                   Low                  Safe
# HILLSBOROUGH                 Low                   Low                  Safe
# HOLMES                       Low                  High                  Safe
# ...                          ...                   ...                   ...
# LEVY                         Low                   Low                   Low
# LIBERTY                      Low                  High                   Low
# MADISON                      Low                  High                   Low
# MANATEE                      Low                   Low                  Safe
# MARION                       Low                   Low                  Safe
# MARTIN                       Low                   Low                  Safe
# MONROE                       Low                   Low                  Safe
# NASSAU                       Low                   Low                  Safe
# OKALOOSA                    High                   Low                  Safe
# OKEECHOBEE                   Low                   Low                  Safe
# ORANGE                       Low                   Low                  Safe
# OSCEOLA                      Low                   Low                   Low
# PALM BEACH                  High                   Low                  Safe
# PASCO                       High                   Low                  Safe
# PINELLAS                     Low                   Low                  Safe
# POLK                         Low                   Low                  Safe
# PUTNAM                       Low                  High                   Low
# ST. JOHNS                   High                   Low                  Safe
# ST. LUCIE                    Low                   Low                  Safe
# SANTA ROSA                  High                   Low                  Safe
# SARASOTA                    High                   Low                  Safe
# SEMINOLE                    High                   Low                  Safe
# SUMTER                       Low                   Low                  Safe
# SUWANNEE                    High                   Low                   Low
# TAYLOR                       Low                  High                   Low
# UNION                        Low                  High                  Safe
# VOLUSIA                      Low                   Low                  Safe
# WAKULLA                      Low                   Low                  Safe
# WALTON                       Low                   Low                  Safe
# WASHINGTON                   Low                   Low                   Low
#
#               Percent Present  AP Participation   AP Pass  (%) ACT Test Takers
# District Name
# ALACHUA                 0.942          0.447156  0.621303               0.6051
# BAKER                   0.917          0.916667  0.041667               0.5836
# BAY                     0.932          0.549970  0.504435               0.5769
# BRADFORD                0.926          0.682927  0.414634               0.6382
# BREVARD                 0.952          0.558824  0.629027               1.0049
# BROWARD                 0.936          0.550099  0.493097               0.5781
# CALHOUN                 0.915               NaN       NaN               0.7075
# CHARLOTTE               0.953          0.650447  0.463754               0.5499
# CITRUS                  0.937          0.724882  0.327714               0.4582
# CLAY                    0.946          0.617097  0.552093               0.6656
# COLLIER                 0.958          0.588729  0.500480               0.7169
# COLUMBIA                0.935          0.614625  0.254941               0.7339
# MIAMI-DADE              0.943          0.566419  0.452086               0.5774
# DESOTO                  0.935          0.943548  0.137097               0.6486
# DIXIE                   0.903          0.774194  0.322581               0.8370
# DUVAL                   0.953          0.554533  0.289586               0.6771
# ESCAMBIA                0.941          0.578523  0.476957               0.6939
# FLAGLER                 0.945          0.644650  0.528402               0.4946
# FRANKLIN                0.902          0.791667  0.250000               0.8182
# GADSDEN                 0.935          0.962963  0.148148               0.5979
# GILCHRIST               0.927               NaN       NaN               0.8552
# GLADES                  0.955          0.875000  0.125000               0.7778
# GULF                    0.928               NaN       NaN               0.6984
# HAMILTON                0.904          0.632184  0.103448               0.8966
# HARDEE                  0.945          0.794425  0.209059               0.7391
# HENDRY                  0.925          0.773451  0.254867               0.7724
# HERNANDO                0.931          0.628003  0.450927               0.5336
# HIGHLANDS               0.942          0.721180  0.372654               0.5681
# HILLSBOROUGH            0.943          0.526788  0.421620               0.5069
# HOLMES                  0.950          0.617647  0.147059               0.7788
# ...                       ...               ...       ...                  ...
# LEVY                    0.899          0.755556  0.225000               0.6908
# LIBERTY                 0.917          0.941176  0.352941               0.8116
# MADISON                 0.928               NaN       NaN               0.8276
# MANATEE                 0.932          0.590836  0.433548               0.6299
# MARION                  0.933          0.660027  0.426959               0.5384
# MARTIN                  0.955          0.591664  0.469200               0.7015
# MONROE                  0.951          0.551986  0.444632               0.6250
# NASSAU                  0.936          0.591942  0.465909               0.6287
# OKALOOSA                0.950          0.590073  0.502179               0.5875
# OKEECHOBEE              0.941          0.619048  0.367965               0.4011
# ORANGE                  0.942          0.567626  0.466944               0.5688
# OSCEOLA                 0.917          0.653977  0.316667               0.6376
# PALM BEACH              0.961          0.513211  0.531377               0.6135
# PASCO                   0.942          0.584793  0.490630               0.6122
# PINELLAS                0.930          0.584694  0.452770               0.6138
# POLK                    0.950          0.636449  0.303193               0.5274
# PUTNAM                  0.889          0.858736  0.133829               1.0594
# ST. JOHNS               0.950          0.524569  0.632118               0.6019
# ST. LUCIE               0.978          0.747714  0.200646               0.5192
# SANTA ROSA              0.945          0.581961  0.604706               0.7067
# SARASOTA                0.957          0.594727  0.655518               0.5284
# SEMINOLE                0.955          0.504011  0.577158               0.5695
# SUMTER                  0.949          0.753281  0.257218               0.5805
# SUWANNEE                0.920          0.649485  0.582474               0.5981
# TAYLOR                  0.911          0.739394  0.230303               0.8696
# UNION                   0.931          0.789474  0.421053               0.8473
# VOLUSIA                 0.938          0.631832  0.426384               0.4621
# WAKULLA                 0.929          0.552448  0.321678               0.5736
# WALTON                  0.943          0.617312  0.330296               0.7021
# WASHINGTON              0.916          0.741071  0.196429               0.7357
#
# [67 rows x 21 columns]

# %% [markdown]
# ### Data Preparation

# %%
#Splitting data for training and testing
X = data.loc[:,['(%) Poverty Rate','Percent Present','(%) ACT Test Takers','AP Participation']]
y = data.loc[:,['(Cat) Dropout Rate']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.76, random_state=17)

# %%
gnb = GaussianNB()
y_gnb_score = gnb.fit(X_train, y_train).predict(X_test)
print(y_gnb_score)

y_expect = y_test
gnb_score = (accuracy_score(y_expect, y_gnb_score))
print(gnb_score)

gnb_score
# Out:
# ['Safe' 'Safe' 'Safe' 'Safe' 'High' 'Safe' 'High' 'Safe' 'Safe' 'Safe'
#  'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe'
#  'Safe' 'High' 'Safe' 'Safe' 'Safe' 'High' 'Safe' 'High' 'Safe' 'Safe'
#  'High' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe'
#  'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'Safe' 'High']
# 0.6875
# 0.6875

# %% [markdown]
# ### NaiveBayes Analysis

# %% [markdown]
# ##### Gaussian NaiveBayes

# %%
#Converting into int arrays for finding ROC curves

def strtoint(array):
    newarray = []
    for i in range(len(array)):
        if array[i] == 'Safe':
            newarray.append(0)
        elif array[i] == 'High':
            newarray.append(1)
    #newarray = newarray.astype(int)
    return newarray

def objtoint(array):
    newarray = []
    for i in range(len(array)):
        if array.iloc[i,0] == 'Safe':
            newarray.append(0)
        elif array.iloc[i,0] == 'High':
            newarray.append(1)
    #newarray = newarray.astype(int)
    return newarray

# %%
y_Score = strtoint(y_gnb_score)

# %%
y_True = objtoint(y_test)

# %%
#I just want to see the values produced for manual calculations... 
TN = 0
FN = 0
TP = 0
FP = 0

for i in range(len(y_True)):
    if (y_Score[i] == 0 and y_True[i] == 0):
        TN += 1
    elif (y_Score[i] == 0 and y_True[i] == 1):
        FN += 1
    elif (y_Score[i] == 1 and y_True[i] == 0):
        FP += 1
    elif (y_Score[i] == 1 and y_True[i] == 1):
        TP += 1
    
print("\n True Negative: %d \n False Negative: %d \n False Positive: %d \n True Positive: %d " % (TN,FN,FP,TP))
# Out:
#  True Negative: 31
#  False Negative: 10
#  False Positive: 5
#  True Positive: 2

# %%
gnb_fpr, gnb_tpr, _ = roc_curve(y_True, y_Score)
gnb_roc_auc = auc(gnb_fpr, gnb_tpr)
print(roc_auc_score(y_True,y_Score))
print(accuracy_score(y_True,y_Score))
# Out:
# 0.513888888889
# 0.6875

# %%
#Note to self:
#The AUC ROC is the P(predicted TRUE|actual TRUE) vs P(FALSE|FALSE), 
#while the overall accuracy is the P=P(TRUE|TRUE)*P(actual TRUE) + P(FALSE|FALSE)*P(actual FALSE).
#hence the low roc score and higher accuracy score

# %% [markdown]
# ##### Multinomial NaiveBayes

# %%
MultiNB = MultinomialNB()

mNB_predic = MultiNB.fit(X_train, y_train).predict(X_test)
print(MultiNB)
print(accuracy_score(y_expect, mNB_predic))
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# 0.75

# %%
y_Score = strtoint(mNB_predic)
mNB_fpr, mNB_tpr, _ = roc_curve(y_True, y_Score)
mNB_roc_auc = auc(mNB_fpr, mNB_tpr)
print(roc_auc_score(y_True,y_Score))
print(accuracy_score(y_True,y_Score))
# Out:
# 0.5
# 0.75

# %% [markdown]
# ### Decision Trees

# %%
dtree = tree.DecisionTreeClassifier()

tree_predic = dtree.fit(X_train, y_train).predict(X_test)
print(MultiNB)
print(accuracy_score(y_expect, tree_predic))
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# 0.6875

# %%
y_Score = strtoint(tree_predic)
tree_fpr, tree_tpr, _ = roc_curve(y_True, y_Score)
tree_roc_auc = auc(tree_fpr, tree_tpr)
print(roc_auc_score(y_True,y_Score))
print(accuracy_score(y_True,y_Score))
# Out:
# 0.569444444444
# 0.6875

# %% [markdown]
# ### ROC Curve Computation

# %%
plt.figure()
lw = 2
plt.plot(gnb_fpr, gnb_tpr, color='limegreen',
        lw=lw, label='Gaussian NB ROC curve (area = %0.3f)' % gnb_roc_auc)
plt.plot([0,1],[0,1], color='pink', lw=lw, linestyle='--')
plt.plot(mNB_fpr, mNB_tpr, color='orange',
        lw=lw, label='Multinomial NB ROC curve (area = %0.3f)' % mNB_roc_auc)
plt.plot(tree_fpr, tree_tpr, color='darkgreen',
        lw=lw, label='Decision Tree ROC curve (area = %0.3f)' % tree_roc_auc)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characterstics curve')
plt.legend(loc='lower right')
plt.show()
